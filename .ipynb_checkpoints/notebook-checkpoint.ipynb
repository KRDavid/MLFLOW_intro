# %%
### IMPORTS ###

import matplotlib.pyplot as plt
import cv2
import os
import random
import tensorflow as tf
import numpy as np
import pandas as pd
import mlflow
from urllib.parse import urlparse


from tensorflow.keras.models import Sequential, Model, load_model
from tensorflow.keras.layers import Conv2D, MaxPooling2D, AveragePooling2D, Activation, Dropout, Flatten, Dense, Dropout
from tensorflow.keras.utils import to_categorical
from tensorflow.keras.callbacks import EarlyStopping
from tensorflow.keras.preprocessing import image
from tensorflow.keras.preprocessing.image import ImageDataGenerator

# %%
tf.random.set_seed(2)

# %%
TRAIN_BASE_DIRECTORY = "./data/test/train"
TEST_BASE_DIRECTORY = "./data/test/test"


image_data_generator = ImageDataGenerator(validation_split=0.5)


TRAIN_IMAGE_SIZE = 32
TRAIN_BATCH_SIZE = 64

# %%
train_generator = image_data_generator.flow_from_directory(
    TRAIN_BASE_DIRECTORY,
    target_size=(TRAIN_IMAGE_SIZE, TRAIN_IMAGE_SIZE),
    batch_size=TRAIN_BATCH_SIZE,
    class_mode='categorical',
    subset='training',
    seed=5)

validation_generator = image_data_generator.flow_from_directory(
    TEST_BASE_DIRECTORY,
    target_size=(TRAIN_IMAGE_SIZE, TRAIN_IMAGE_SIZE),
    batch_size=TRAIN_BATCH_SIZE,
    class_mode='categorical',
    subset='training',
    seed=5)
# Out:
# Found 500 images belonging to 2 classes.
# Found 100 images belonging to 2 classes.

# %%
def train_model(kernel1, kernel2, kernel3, epochs):
      
    model = Sequential()

    model.add(Conv2D(32, kernel_size=kernel1, activation='relu', padding='same', input_shape=(32,32,3))) 
    model.add(MaxPooling2D(pool_size=(2, 2)))
    model.add(Dense(64, activation='relu'))
    model.add(Dropout(0.2))

    model.add(Conv2D(64, kernel_size=kernel2, padding='same', activation='relu'))
    model.add(MaxPooling2D(pool_size=(2, 2)))
    model.add(Dense(128, activation='relu'))
    model.add(Dropout(0.2))

    model.add(Conv2D(128, kernel_size=kernel3, padding='same', activation='relu'))

    #Fin obligatoire
    model.add(Flatten())
    model.add(Dense(2, activation='softmax'))

    model.summary()

    model.compile(optimizer='adam', loss='categorical_crossentropy', metrics=['accuracy'])

    training = model.fit_generator(train_generator, epochs=epochs, validation_data=validation_generator, shuffle=False)
   
    with mlflow.start_run():
        mlflow.log_param("T kernel 1conv", kernel1)
        mlflow.log_param("T kernel 2conv", kernel2)
        mlflow.log_param("T kernel 3conv", kernel3)
        mlflow.log_param("Epochs", epochs)
        mlflow.log_metric("acc", training.history["accuracy"][-1])
        mlflow.log_metric("val acc", training.history["val_accuracy"][-1])
        
        mlflow.keras.log_model(model, "model")

# %%
train_model(3, 3, 3, 10)
# Out:
# Model: "sequential_7"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d_21 (Conv2D)           (None, 32, 32, 32)        896
# _________________________________________________________________
# max_pooling2d_14 (MaxPooling (None, 16, 16, 32)        0
# _________________________________________________________________
# dense_21 (Dense)             (None, 16, 16, 64)        2112
# _________________________________________________________________
# dropout_14 (Dropout)         (None, 16, 16, 64)        0
# _________________________________________________________________
# conv2d_22 (Conv2D)           (None, 16, 16, 64)        36928
# _________________________________________________________________
# max_pooling2d_15 (MaxPooling (None, 8, 8, 64)          0
# _________________________________________________________________
# dense_22 (Dense)             (None, 8, 8, 128)         8320
# _________________________________________________________________
# dropout_15 (Dropout)         (None, 8, 8, 128)         0
# _________________________________________________________________
# conv2d_23 (Conv2D)           (None, 8, 8, 128)         147584
# _________________________________________________________________
# flatten_7 (Flatten)          (None, 8192)              0
# _________________________________________________________________
# dense_23 (Dense)             (None, 2)                 16386
# =================================================================
# Total params: 212,226
# Trainable params: 212,226
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/10
# 8/8 [==============================] - 1s 144ms/step - loss: 13.6639 - accuracy: 0.5700 - val_loss: 1.1643 - val_accuracy: 0.5200
# Epoch 2/10
# 8/8 [==============================] - 1s 120ms/step - loss: 0.8410 - accuracy: 0.6580 - val_loss: 0.5025 - val_accuracy: 0.7100
# Epoch 3/10
# 8/8 [==============================] - 1s 119ms/step - loss: 0.4146 - accuracy: 0.8280 - val_loss: 0.2490 - val_accuracy: 0.9300
# Epoch 4/10
# 8/8 [==============================] - 1s 130ms/step - loss: 0.2847 - accuracy: 0.8720 - val_loss: 0.2368 - val_accuracy: 0.9300
# Epoch 5/10
# 8/8 [==============================] - 1s 124ms/step - loss: 0.2461 - accuracy: 0.8900 - val_loss: 0.1723 - val_accuracy: 0.9200
# Epoch 6/10
# 8/8 [==============================] - 1s 117ms/step - loss: 0.1735 - accuracy: 0.9300 - val_loss: 0.1422 - val_accuracy: 0.9500
# Epoch 7/10
# 8/8 [==============================] - 1s 115ms/step - loss: 0.1494 - accuracy: 0.9520 - val_loss: 0.1541 - val_accuracy: 0.9400
# Epoch 8/10
# 8/8 [==============================] - 1s 128ms/step - loss: 0.1615 - accuracy: 0.9420 - val_loss: 0.1893 - val_accuracy: 0.9200
# Epoch 9/10
# 8/8 [==============================] - 1s 156ms/step - loss: 0.1663 - accuracy: 0.9420 - val_loss: 0.1769 - val_accuracy: 0.9000
# Epoch 10/10
# 8/8 [==============================] - 1s 139ms/step - loss: 0.1358 - accuracy: 0.9560 - val_loss: 0.1294 - val_accuracy: 0.9700

# %%
train_model(3, 3, 3, 20)
# Out:
# Model: "sequential_8"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d_24 (Conv2D)           (None, 32, 32, 32)        896
# _________________________________________________________________
# max_pooling2d_16 (MaxPooling (None, 16, 16, 32)        0
# _________________________________________________________________
# dense_24 (Dense)             (None, 16, 16, 64)        2112
# _________________________________________________________________
# dropout_16 (Dropout)         (None, 16, 16, 64)        0
# _________________________________________________________________
# conv2d_25 (Conv2D)           (None, 16, 16, 64)        36928
# _________________________________________________________________
# max_pooling2d_17 (MaxPooling (None, 8, 8, 64)          0
# _________________________________________________________________
# dense_25 (Dense)             (None, 8, 8, 128)         8320
# _________________________________________________________________
# dropout_17 (Dropout)         (None, 8, 8, 128)         0
# _________________________________________________________________
# conv2d_26 (Conv2D)           (None, 8, 8, 128)         147584
# _________________________________________________________________
# flatten_8 (Flatten)          (None, 8192)              0
# _________________________________________________________________
# dense_26 (Dense)             (None, 2)                 16386
# =================================================================
# Total params: 212,226
# Trainable params: 212,226
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/20
# 8/8 [==============================] - 1s

# Out:
# Model: "sequential_12"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d_36 (Conv2D)           (None, 32, 32, 32)        896
# _________________________________________________________________
# max_pooling2d_24 (MaxPooling (None, 16, 16, 32)        0
# _________________________________________________________________
# dense_36 (Dense)             (None, 16, 16, 64)        2112
# _________________________________________________________________
# dropout_24 (Dropout)         (None, 16, 16, 64)        0
# _________________________________________________________________
# conv2d_37 (Conv2D)           (None, 16, 16, 64)        36928
# _________________________________________________________________
# max_pooling2d_25 (MaxPooling (None, 8, 8, 64)          0
# _________________________________________________________________
# dense_37 (Dense)             (None, 8, 8, 128)         8320
# _________________________________________________________________
# dropout_25 (Dropout)         (None, 8, 8, 128)         0
# _________________________________________________________________
# conv2d_38 (Conv2D)           (None, 8, 8, 128)         147584
# _________________________________________________________________
# flatten_12 (Flatten)         (None, 8192)              0
# _________________________________________________________________
# dense_38 (Dense)             (None, 2)                 16386
# =================================================================
# Total params: 212,226
# Trainable params: 212,226
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/5
# 8/8 [==============================] - 1s 155ms/step - loss: 23.1265 - accuracy: 0.5020 - val_loss: 0.6502 - val_accuracy: 0.6000
# Epoch 2/5
# 8/8 [==============================] - 1s 108ms/step - loss: 1.3386 - accuracy: 0.5720 - val_loss: 0.6552 - val_accuracy: 0.5600
# Epoch 3/5
# 8/8 [==============================] - 1s 108ms/step - loss: 0.7124 - accuracy: 0.5500 - val_loss: 0.5474 - val_accuracy: 0.7900
# Epoch 4/5
# 8/8 [==============================] - 1s 116ms/step - loss: 0.5659 - accuracy: 0.7020 - val_loss: 0.4767 - val_accuracy: 0.8400
# Epoch 5/5
# 8/8 [==============================] - 1s 115ms/step - loss: 0.4311 - accuracy: 0.8360 - val_loss: 0.4178 - val_accuracy: 0.8000

# %%
train_model(7, 5, 3, 20)
# Out:
# Model: "sequential_13"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d_39 (Conv2D)           (None, 32, 32, 32)        4736
# _________________________________________________________________
# max_pooling2d_26 (MaxPooling (None, 16, 16, 32)        0
# _________________________________________________________________
# dense_39 (Dense)             (None, 16, 16, 64)        2112
# _________________________________________________________________
# dropout_26 (Dropout)         (None, 16, 16, 64)        0
# _________________________________________________________________
# conv2d_40 (Conv2D)           (None, 16, 16, 64)        102464
# _________________________________________________________________
# max_pooling2d_27 (MaxPooling (None, 8, 8, 64)          0
# _________________________________________________________________
# dense_40 (Dense)             (None, 8, 8, 128)         8320
# _________________________________________________________________
# dropout_27 (Dropout)         (None, 8, 8, 128)         0
# _________________________________________________________________
# conv2d_41 (Conv2D)           (None, 8, 8, 128)         147584
# _________________________________________________________________
# flatten_13 (Flatten)         (None, 8192)              0
# _________________________________________________________________
# dense_41 (Dense)             (None, 2)                 16386
# =================================================================
# Total params: 281,602
# Trainable params: 281,602
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/20
# 8/8 [==============================] - 1s 174ms/step - loss: 14.3259 - accuracy: 0.5220 - val_loss: 0.3419 - val_accuracy: 0.8400
# Epoch 2/20
# 8/8 [==============================] - 1s 143ms/step - loss: 0.6846 - accuracy: 0.6960 - val_loss: 0.7742 - val_accuracy: 0.5600
# Epoch 3/20
# 8/8 [==============================] - 1s 143ms/step - loss: 0.4560 - accuracy: 0.7900 - val_loss: 0.3007 - val_accuracy: 0.8900
# Epoch 4/20
# 8/8 [==============================] - 1s 143ms/step - loss: 0.3098 - accuracy: 0.8500 - val_loss: 0.2311 - val_accuracy: 0.9000
# Epoch 5/20
# 8/8 [==============================] - 1s 148ms/step - loss: 0.2440 - accuracy: 0.8920 - val_loss: 0.2515 - val_accuracy: 0.8800
# Epoch 6/20
# 8/8 [==============================] - 1s 150ms/step - loss: 0.2262 - accuracy: 0.9100 - val_loss: 0.1869 - val_accuracy: 0.9100
# Epoch 7/20
# 8/8 [==============================] - 1s 149ms/step - loss: 0.2100 - accuracy: 0.9020 - val_loss: 0.2542 - val_accuracy: 0.8600
# Epoch 8/20
# 8/8 [==============================] - 1s 141ms/step - loss: 0.2015 - accuracy: 0.9120 - val_loss: 0.1638 - val_accuracy: 0.9400
# Epoch 9/20
# 8/8 [==============================] - 1s 142ms/step - loss: 0.1590 - accuracy: 0.9300 - val_loss: 0.1740 - val_accuracy: 0.9400
# Epoch 10/20
# 8/8 [==============================] - 1s 142ms/step - loss: 0.1529 - accuracy: 0.9440 - val_loss: 0.1886 - val_accuracy: 0.9100
# Epoch 11/20
# 8/8 [==============================] - 1s 140ms/step - loss: 0.1611 - accuracy: 0.9380 - val_loss: 0.1670 - val_accuracy: 0.9300
# Epoch 12/20
# 8/8 [==============================] - 1s 142ms/step - loss: 0.1367 - accuracy: 0.9480 - val_loss: 0.2056 - val_accuracy: 0.9300
# Epoch 13/20
# 8/8 [==============================] - 1s 143ms/step - loss: 0.0999 - accuracy: 0.9560 - val_loss: 0.1239 - val_accuracy: 0.9500
# Epoch 14/20
# 8/8 [==============================] - 1s 139ms/step - loss: 0.0910 - accuracy: 0.9640 - val_loss: 0.1231 - val_accuracy: 0.9400
# Epoch 15/20
# 8/8 [==============================] - 1s 140ms/step - loss: 0.1056 - accuracy: 0.9620 - val_loss: 0.1183 - val_accuracy: 0.9700
# Epoch 16/20
# 8/8 [==============================] - 1s 138ms/step - loss: 0.0963 - accuracy: 0.9600 - val_loss: 0.1136 - val_accuracy: 0.9700
# Epoch 17/20
# 8/8 [==============================] - 1s 150ms/step - loss: 0.0753 - accuracy: 0.9800 - val_loss: 0.1719 - val_accuracy: 0.9200
# Epoch 18/20
# 8/8 [==============================] - 1s 148ms/step - loss: 0.1044 - accuracy: 0.9620 - val_loss: 0.1171 - val_accuracy: 0.9600
# Epoch 19/20
# 8/8 [==============================] - 1s 142ms/step - loss: 0.1029 - accuracy: 0.9680 - val_loss: 0.1128 - val_accuracy: 0.9900
# Epoch 20/20
# 8/8 [==============================] - 1s 155ms/step - loss: 0.0821 - accuracy: 0.9720 - val_loss: 0.2129 - val_accuracy: 0.9100
