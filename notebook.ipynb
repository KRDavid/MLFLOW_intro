# %%
### IMPORTS ###

import matplotlib.pyplot as plt
import cv2
import os
import random
import tensorflow as tf
import numpy as np
import pandas as pd
import mlflow
from urllib.parse import urlparse


from tensorflow.keras.models import Sequential, Model, load_model
from tensorflow.keras.layers import Conv2D, MaxPooling2D, AveragePooling2D, Activation, Dropout, Flatten, Dense, Dropout
from tensorflow.keras.utils import to_categorical
from tensorflow.keras.callbacks import EarlyStopping
from tensorflow.keras.preprocessing import image
from tensorflow.keras.preprocessing.image import ImageDataGenerator

# %%
tf.random.set_seed(2)

# %%
TRAIN_BASE_DIRECTORY = "./data/test/train"
TEST_BASE_DIRECTORY = "./data/test/test"


image_data_generator = ImageDataGenerator(validation_split=0.5)


TRAIN_IMAGE_SIZE = 32
TRAIN_BATCH_SIZE = 64

# %%
train_generator = image_data_generator.flow_from_directory(
    TRAIN_BASE_DIRECTORY,
    target_size=(TRAIN_IMAGE_SIZE, TRAIN_IMAGE_SIZE),
    batch_size=TRAIN_BATCH_SIZE,
    class_mode='categorical',
    subset='training',
    seed=5)

validation_generator = image_data_generator.flow_from_directory(
    TEST_BASE_DIRECTORY,
    target_size=(TRAIN_IMAGE_SIZE, TRAIN_IMAGE_SIZE),
    batch_size=TRAIN_BATCH_SIZE,
    class_mode='categorical',
    subset='training',
    seed=5)
# Out:
# Found 500 images belonging to 2 classes.
# Found 100 images belonging to 2 classes.

# %%
def train_model(kernel1, kernel2, kernel3, epochs):
      
    model = Sequential()

    model.add(Conv2D(32, kernel_size=kernel1, activation='relu', padding='same', input_shape=(32,32,3))) 
    model.add(MaxPooling2D(pool_size=(2, 2)))
    model.add(Dense(64, activation='relu'))
    model.add(Dropout(0.2))

    model.add(Conv2D(64, kernel_size=kernel2, padding='same', activation='relu'))
    model.add(MaxPooling2D(pool_size=(2, 2)))
    model.add(Dense(128, activation='relu'))
    model.add(Dropout(0.2))

    model.add(Conv2D(128, kernel_size=kernel3, padding='same', activation='relu'))

    #Fin obligatoire
    model.add(Flatten())
    model.add(Dense(2, activation='softmax'))

    model.summary()

    model.compile(optimizer='adam', loss='categorical_crossentropy', metrics=['accuracy'])

    training = model.fit_generator(train_generator, epochs=epochs, validation_data=validation_generator, shuffle=False)
   
    with mlflow.start_run():
        mlflow.log_param("T kernel 1conv", kernel1)
        mlflow.log_param("T kernel 2conv", kernel2)
        mlflow.log_param("T kernel 3conv", kernel3)
        mlflow.log_param("Epochs", epochs)
        mlflow.log_metric("acc", training.history["accuracy"][-1])
        mlflow.log_metric("val acc", training.history["val_accuracy"][-1])

# %%
train_model(3, 3, 3, 10)
# Out:
# Model: "sequential_9"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d_24 (Conv2D)           (None, 32, 32, 32)        896
# _________________________________________________________________
# max_pooling2d_16 (MaxPooling (None, 16, 16, 32)        0
# _________________________________________________________________
# dense_24 (Dense)             (None, 16, 16, 64)        2112
# _________________________________________________________________
# dropout_16 (Dropout)         (None, 16, 16, 64)        0
# _________________________________________________________________
# conv2d_25 (Conv2D)           (None, 16, 16, 64)        36928
# _________________________________________________________________
# max_pooling2d_17 (MaxPooling (None, 8, 8, 64)          0
# _________________________________________________________________
# dense_25 (Dense)             (None, 8, 8, 128)         8320
# _________________________________________________________________
# dropout_17 (Dropout)         (None, 8, 8, 128)         0
# _________________________________________________________________
# conv2d_26 (Conv2D)           (None, 8, 8, 128)         147584
# _________________________________________________________________
# flatten_8 (Flatten)          (None, 8192)              0
# _________________________________________________________________
# dense_26 (Dense)             (None, 2)                 16386
# =================================================================
# Total params: 212,226
# Trainable params: 212,226
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/10
# 8/8 [==============================] - 1s 113ms/step - loss: 20.9751 - accuracy: 0.5440 - val_loss: 1.3675 - val_accuracy: 0.5000
# Epoch 2/10
# 8/8 [==============================] - 1s 90ms/step - loss: 0.9290 - accuracy: 0.6160 - val_loss: 0.4249 - val_accuracy: 0.8300
# Epoch 3/10
# 8/8 [==============================] - 1s 90ms/step - loss: 0.4629 - accuracy: 0.7600 - val_loss: 0.3247 - val_accuracy: 0.8700
# Epoch 4/10
# 8/8 [==============================] - 1s 93ms/step - loss: 0.2733 - accuracy: 0.8940 - val_loss: 0.2140 - val_accuracy: 0.9100
# Epoch 5/10
# 8/8 [==============================] - 1s 92ms/step - loss: 0.2219 - accuracy: 0.9000 - val_loss: 0.1889 - val_accuracy: 0.9400
# Epoch 6/10
# 8/8 [==============================] - 1s 88ms/step - loss: 0.1809 - accuracy: 0.9260 - val_loss: 0.1708 - val_accuracy: 0.9600
# Epoch 7/10
# 8/8 [==============================] - 1s 91ms/step - loss: 0.1623 - accuracy: 0.9340 - val_loss: 0.1503 - val_accuracy: 0.9600
# Epoch 8/10
# 8/8 [==============================] - 1s 93ms/step - loss: 0.1428 - accuracy: 0.9360 - val_loss: 0.1392 - val_accuracy: 0.9600
# Epoch 9/10
# 8/8 [==============================] - 1s 100ms/step - loss: 0.1394 - accuracy: 0.9440 - val_loss: 0.1587 - val_accuracy: 0.9500
# Epoch 10/10
# 8/8 [==============================] - 1s 95ms/step - loss: 0.1125 - accuracy: 0.9540 - val_loss: 0.1325 - val_accuracy: 0.9500
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-18-27f89a899513> in <module>
# ----> 1 train_model(3, 3, 3, 10)
#
# <ipython-input-17-9a37b7ec8e6b> in train_model(kernel1, kernel2, kernel3, epochs)
#      32         mlflow.log_metric("val acc", training.history["val_accuracy"][-1])
#      33
# ---> 34         mlflow.tensorflow.log_model("model")
#
# D:\Anaconda\envs\sandbox\lib\site-packages\mlflow\utils\annotations.py in wrapper(*args, **kwargs)
#      58     def wrapper(*args, **kwargs):
#      59         if len(args) > 0:
# ---> 60             raise TypeError("Method %s only takes keyword arguments." % func.__name__)
#      61         return func(**kwargs)
#      62
#
# TypeError: Method log_model only takes keyword arguments.

# %%
train_model(3, 3, 3, 20)
# Out:
# Model: "sequential_2"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d_3 (Conv2D)            (None, 32, 32, 32)        896
# _________________________________________________________________
# max_pooling2d_2 (MaxPooling2 (None, 16, 16, 32)        0
# _________________________________________________________________
# dense_3 (Dense)              (None, 16, 16, 64)        2112
# _________________________________________________________________
# dropout_2 (Dropout)          (None, 16, 16, 64)        0
# _________________________________________________________________
# conv2d_4 (Conv2D)            (None, 16, 16, 64)        36928
# _________________________________________________________________
# max_pooling2d_3 (MaxPooling2 (None, 8, 8, 64)          0
# _________________________________________________________________
# dense_4 (Dense)              (None, 8, 8, 128)         8320
# _________________________________________________________________
# dropout_3 (Dropout)          (None, 8, 8, 128)         0
# _________________________________________________________________
# conv2d_5 (Conv2D)            (None, 8, 8, 128)         147584
# _________________________________________________________________
# flatten_1 (Flatten)          (None, 8192)              0
# _________________________________________________________________
# dense_5 (Dense)              (None, 2)                 16386
# =================================================================
# Total params: 212,226
# Trainable params: 212,226
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/20
# 8/8 [==============================] - 1s 110ms/step - loss: 22.3190 - accuracy: 0.4840 - val_loss: 2.0215 - val_accuracy: 0.5000
# Epoch 2/20
# 8/8 [==============================] - 1s 85ms/step - loss: 0.9072 - accuracy: 0.6160 - val_loss: 0.5610 - val_accuracy: 0.7200
# Epoch 3/20
# 8/8 [==============================] - 1s 88ms/step - loss: 0.5345 - accuracy: 0.7440 - val_loss: 0.3760 - val_accuracy: 0.8300
# Epoch 4/20
# 8/8 [==============================] - 1s 94ms/step - loss: 0.3568 - accuracy: 0.8320 - val_loss: 0.2804 - val_accuracy: 0.9000
# Epoch 5/20
# 8/8 [==============================] - 1s 91ms/step - loss: 0.3313 - accuracy: 0.8760 - val_loss: 0.3532 - val_accuracy: 0.8700
# Epoch 6/20
# 8/8 [==============================] - 1s 91ms/step - loss: 0.3234 - accuracy: 0.8600 - val_loss: 0.2119 - val_accuracy: 0.9100
# Epoch 7/20
# 8/8 [==============================] - 1s 91ms/step - loss: 0.2697 - accuracy: 0.9040 - val_loss: 0.2311 - val_accuracy: 0.9000
# Epoch 8/20
# 8/8 [==============================] - 1s 91ms/step - loss: 0.2406 - accuracy: 0.8880 - val_loss: 0.2031 - val_accuracy: 0.9400
# Epoch 9/20
# 8/8 [==============================] - 1s 88ms/step - loss: 0.2018 - accuracy: 0.9220 - val_loss: 0.1559 - val_accuracy: 0.9400
# Epoch 10/20
# 8/8 [==============================] - 1s 88ms/step - loss: 0.1469 - accuracy: 0.9400 - val_loss: 0.1674 - val_accuracy: 0.9500
# Epoch 11/20
# 8/8 [==============================] - 1s 88ms/step - loss: 0.1728 - accuracy: 0.9340 - val_loss: 0.1484 - val_accuracy: 0.9400
# Epoch 12/20
# 8/8 [==============================] - 1s 86ms/step - loss: 0.1226 - accuracy: 0.9560 - val_loss: 0.1353 - val_accuracy: 0.9600
# Epoch 13/20
# 8/8 [==============================] - 1s 87ms/step - loss: 0.1171 - accuracy: 0.9540 - val_loss: 0.1307 - val_accuracy: 0.9600
# Epoch 14/20
# 8/8 [==============================] - 1s 87ms/step - loss: 0.1084 - accuracy: 0.9620 - val_loss: 0.1203 - val_accuracy: 0.9500
# Epoch 15/20
# 8/8 [==============================] - 1s 87ms/step - loss: 0.1066 - accuracy: 0.9580 - val_loss: 0.1202 - val_accuracy: 0.9500
# Epoch 16/20
# 8/8 [==============================] - 1s 85ms/step - loss: 0.0856 - accuracy: 0.9680 - val_loss: 0.1279 - val_accuracy: 0.9500
# Epoch 17/20
# 8/8 [==============================] - 1s 85ms/step - loss: 0.0777 - accuracy: 0.9760 - val_loss: 0.1066 - val_accuracy: 0.9700
# Epoch 18/20
# 8/8 [==============================] - 1s 84ms/step - loss: 0.0589 - accuracy: 0.9760 - val_loss: 0.0871 - val_accuracy: 0.9600
# Epoch 19/20
# 8/8 [==============================] - 1s 85ms/step - loss: 0.0537 - accuracy: 0.9800 - val_loss: 0.0850 - val_accuracy: 0.9600
# Epoch 20/20
# 8/8 [==============================] - 1s 85ms/step - loss: 0.0374 - accuracy: 0.9860 - val_loss: 0.1621 - val_accuracy: 0.9400

# %%
train_model(3, 5, 7, 10)
# Out:
# Model: "sequential_3"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d_6 (Conv2D)            (None, 32, 32, 32)        896
# _________________________________________________________________
# max_pooling2d_4 (MaxPooling2 (None, 16, 16, 32)        0
# _________________________________________________________________
# dense_6 (Dense)              (None, 16, 16, 64)        2112
# _________________________________________________________________
# dropout_4 (Dropout)          (None, 16, 16, 64)        0
# _________________________________________________________________
# conv2d_7 (Conv2D)            (None, 16, 16, 64)        102464
# _________________________________________________________________
# max_pooling2d_5 (MaxPooling2 (None, 8, 8, 64)          0
# _________________________________________________________________
# dense_7 (Dense)              (None, 8, 8, 128)         8320
# _________________________________________________________________
# dropout_5 (Dropout)          (None, 8, 8, 128)         0
# _________________________________________________________________
# conv2d_8 (Conv2D)            (None, 8, 8, 128)         802944
# _________________________________________________________________
# flatten_2 (Flatten)          (None, 8192)              0
# _________________________________________________________________
# dense_8 (Dense)              (None, 2)                 16386
# =================================================================
# Total params: 933,122
# Trainable params: 933,122
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/10
# 8/8 [==============================] - 2s 212ms/step - loss: 33.3648 - accuracy: 0.4780 - val_loss: 0.6018 - val_accuracy: 0.7000
# Epoch 2/10
# 8/8 [==============================] - 2s 193ms/step - loss: 0.7745 - accuracy: 0.5300 - val_loss: 0.7020 - val_accuracy: 0.4800
# Epoch 3/10
# 8/8 [==============================] - 2s 194ms/step - loss: 0.6347 - accuracy: 0.6500 - val_loss: 0.5511 - val_accuracy: 0.6900
# Epoch 4/10
# 8/8 [==============================] - 2s 207ms/step - loss: 0.5143 - accuracy: 0.7300 - val_loss: 0.5796 - val_accuracy: 0.6100
# Epoch 5/10
# 8/8 [==============================] - 2s 197ms/step - loss: 0.3865 - accuracy: 0.8080 - val_loss: 0.2137 - val_accuracy: 0.9200
# Epoch 6/10
# 8/8 [==============================] - 2s 221ms/step - loss: 0.2681 - accuracy: 0.9020 - val_loss: 0.2498 - val_accuracy: 0.8700
# Epoch 7/10
# 8/8 [==============================] - 2s 195ms/step - loss: 0.1651 - accuracy: 0.9360 - val_loss: 0.1636 - val_accuracy: 0.9400
# Epoch 8/10
# 8/8 [==============================] - 1s 183ms/step - loss: 0.2110 - accuracy: 0.9260 - val_loss: 0.2809 - val_accuracy: 0.8600
# Epoch 9/10
# 8/8 [==============================] - 1s 183ms/step - loss: 0.1715 - accuracy: 0.9380 - val_loss: 0.1434 - val_accuracy: 0.9600
# Epoch 10/10
# 8/8 [==============================] - 2s 214ms/step - loss: 0.1359 - accuracy: 0.9560 - val_loss: 0.1892 - val_accuracy: 0.9400

# %%
train_model(3, 5, 7, 20)
# Out:
# Model: "sequential_4"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d_9 (Conv2D)            (None, 32, 32, 32)        896
# _________________________________________________________________
# max_pooling2d_6 (MaxPooling2 (None, 16, 16, 32)        0
# _________________________________________________________________
# dense_9 (Dense)              (None, 16, 16, 64)        2112
# _________________________________________________________________
# dropout_6 (Dropout)          (None, 16, 16, 64)        0
# _________________________________________________________________
# conv2d_10 (Conv2D)           (None, 16, 16, 64)        102464
# _________________________________________________________________
# max_pooling2d_7 (MaxPooling2 (None, 8, 8, 64)          0
# _________________________________________________________________
# dense_10 (Dense)             (None, 8, 8, 128)         8320
# _________________________________________________________________
# dropout_7 (Dropout)          (None, 8, 8, 128)         0
# _________________________________________________________________
# conv2d_11 (Conv2D)           (None, 8, 8, 128)         802944
# _________________________________________________________________
# flatten_3 (Flatten)          (None, 8192)              0
# _________________________________________________________________
# dense_11 (Dense)             (None, 2)                 16386
# =================================================================
# Total params: 933,122
# Trainable params: 933,122
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/20
# 8/8 [==============================] - 2s 268ms/step - loss: 14.6430 - accuracy: 0.6140 - val_loss: 0.4836 - val_accuracy: 0.7400
# Epoch 2/20
# 8/8 [==============================] - 2s 224ms/step - loss: 0.6305 - accuracy: 0.6420 - val_loss: 0.5002 - val_accuracy: 0.8700
# Epoch 3/20
# 8/8 [==============================] - 2s 219ms/step - loss: 0.3846 - accuracy: 0.8340 - val_loss: 0.2569 - val_accuracy: 0.8900
# Epoch 4/20
# 8/8 [==============================] - 2s 216ms/step - loss: 0.3811 - accuracy: 0.8660 - val_loss: 0.2975 - val_accuracy: 0.8800
# Epoch 5/20
# 8/8 [==============================] - 2s 202ms/step - loss: 0.3047 - accuracy: 0.8600 - val_loss: 0.3084 - val_accuracy: 0.8500
# Epoch 6/20
# 8/8 [==============================] - 2s 209ms/step - loss: 0.2307 - accuracy: 0.9080 - val_loss: 0.2013 - val_accuracy: 0.9000
# Epoch 7/20
# 8/8 [==============================] - 2s 218ms/step - loss: 0.2196 - accuracy: 0.9040 - val_loss: 0.1947 - val_accuracy: 0.9400
# Epoch 8/20
# 8/8 [==============================] - 2s 219ms/step - loss: 0.1951 - accuracy: 0.9240 - val_loss: 0.1619 - val_accuracy: 0.9400
# Epoch 9/20
# 8/8 [==============================] - 2s 218ms/step - loss: 0.1448 - accuracy: 0.9460 - val_loss: 0.1347 - val_accuracy: 0.9400
# Epoch 10/20
# 8/8 [==============================] - 2s 228ms/step - loss: 0.1226 - accuracy: 0.9520 - val_loss: 0.1211 - val_accuracy: 0.9600
# Epoch 11/20
# 8/8 [==============================] - 2s 225ms/step - loss: 0.0995 - accuracy: 0.9620 - val_loss: 0.1393 - val_accuracy: 0.9400
# Epoch 12/20
# 8/8 [==============================] - 2s 223ms/step - loss: 0.1030 - accuracy: 0.9640 - val_loss: 0.1621 - val_accuracy: 0.9400
# Epoch 13/20
# 8/8 [==============================] - 2s 210ms/step - loss: 0.0744 - accuracy: 0.9720 - val_loss: 0.1170 - val_accuracy: 0.9400
# Epoch 14/20
# 8/8 [==============================] - 2s 217ms/step - loss: 0.0805 - accuracy: 0.9560 - val_loss: 0.1562 - val_accuracy: 0.9200
# Epoch 15/20
# 8/8 [==============================] - 2s 200ms/step - loss: 0.0757 - accuracy: 0.9680 - val_loss: 0.1928 - val_accuracy: 0.9100
# Epoch 16/20
# 8/8 [==============================] - 2s 207ms/step - loss: 0.0561 - accuracy: 0.9720 - val_loss: 0.1046 - val_accuracy: 0.9300
# Epoch 17/20
# 8/8 [==============================] - 2s 217ms/step - loss: 0.0378 - accuracy: 0.9880 - val_loss: 0.1163 - val_accuracy: 0.9600
# Epoch 18/20
# 8/8 [==============================] - 2s 213ms/step - loss: 0.0407 - accuracy: 0.9820 - val_loss: 0.0949 - val_accuracy: 0.9700
# Epoch 19/20
# 8/8 [==============================] - 2s 205ms/step - loss: 0.0389 - accuracy: 0.9900 - val_loss: 0.1377 - val_accuracy: 0.9500
# Epoch 20/20
# 8/8 [==============================] - 2s 201ms/step - loss: 0.0385 - accuracy: 0.9840 - val_loss: 0.1601 - val_accuracy: 0.9300

# %%
train_model(3, 5, 5, 20)
# Out:
# Model: "sequential_5"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d_12 (Conv2D)           (None, 32, 32, 32)        896
# _________________________________________________________________
# max_pooling2d_8 (MaxPooling2 (None, 16, 16, 32)        0
# _________________________________________________________________
# dense_12 (Dense)             (None, 16, 16, 64)        2112
# _________________________________________________________________
# dropout_8 (Dropout)          (None, 16, 16, 64)        0
# _________________________________________________________________
# conv2d_13 (Conv2D)           (None, 16, 16, 64)        102464
# _________________________________________________________________
# max_pooling2d_9 (MaxPooling2 (None, 8, 8, 64)          0
# _________________________________________________________________
# dense_13 (Dense)             (None, 8, 8, 128)         8320
# _________________________________________________________________
# dropout_9 (Dropout)          (None, 8, 8, 128)         0
# _________________________________________________________________
# conv2d_14 (Conv2D)           (None, 8, 8, 128)         409728
# _________________________________________________________________
# flatten_4 (Flatten)          (None, 8192)              0
# _________________________________________________________________
# dense_14 (Dense)             (None, 2)                 16386
# =================================================================
# Total params: 539,906
# Trainable params: 539,906
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/20
# 8/8 [==============================] - 1s 149ms/step - loss: 21.7605 - accuracy: 0.5140 - val_loss: 1.0931 - val_accuracy: 0.6700
# Epoch 2/20
# 8/8 [==============================] - 1s 125ms/step - loss: 0.8550 - accuracy: 0.6820 - val_loss: 0.5093 - val_accuracy: 0.6900
# Epoch 3/20
# 8/8 [==============================] - 1s 164ms/step - loss: 0.5687 - accuracy: 0.7300 - val_loss: 0.3609 - val_accuracy: 0.8600
# Epoch 4/20
# 8/8 [==============================] - 1s 146ms/step - loss: 0.3639 - accuracy: 0.8280 - val_loss: 0.2927 - val_accuracy: 0.8400
# Epoch 5/20
# 8/8 [==============================] - 1s 139ms/step - loss: 0.3509 - accuracy: 0.8360 - val_loss: 0.2481 - val_accuracy: 0.9200
# Epoch 6/20
# 8/8 [==============================] - 1s 139ms/step - loss: 0.2906 - accuracy: 0.8960 - val_loss: 0.3497 - val_accuracy: 0.8200
# Epoch 7/20
# 8/8 [==============================] - 1s 145ms/step - loss: 0.2437 - accuracy: 0.8880 - val_loss: 0.2291 - val_accuracy: 0.9000
# Epoch 8/20
# 8/8 [==============================] - 1s 136ms/step - loss: 0.2265 - accuracy: 0.9060 - val_loss: 0.2598 - val_accuracy: 0.8700
# Epoch 9/20
# 8/8 [==============================] - 1s 134ms/step - loss: 0.2067 - accuracy: 0.9140 - val_loss: 0.2265 - val_accuracy: 0.9100
# Epoch 10/20
# 8/8 [==============================] - 1s 136ms/step - loss: 0.2038 - accuracy: 0.9100 - val_loss: 0.2083 - val_accuracy: 0.9300
# Epoch 11/20
# 8/8 [==============================] - 1s 133ms/step - loss: 0.1800 - accuracy: 0.9360 - val_loss: 0.1705 - val_accuracy: 0.9400
# Epoch 12/20
# 8/8 [==============================] - 1s 130ms/step - loss: 0.1657 - accuracy: 0.9280 - val_loss: 0.1882 - val_accuracy: 0.9300
# Epoch 13/20
# 8/8 [==============================] - 1s 126ms/step - loss: 0.1880 - accuracy: 0.9320 - val_loss: 0.1740 - val_accuracy: 0.9200
# Epoch 14/20
# 8/8 [==============================] - 1s 143ms/step - loss: 0.1725 - accuracy: 0.9380 - val_loss: 0.1674 - val_accuracy: 0.9300
# Epoch 15/20
# 8/8 [==============================] - 1s 137ms/step - loss: 0.1340 - accuracy: 0.9440 - val_loss: 0.1343 - val_accuracy: 0.9500
# Epoch 16/20
# 8/8 [==============================] - 1s 139ms/step - loss: 0.1148 - accuracy: 0.9600 - val_loss: 0.1519 - val_accuracy: 0.9400
# Epoch 17/20
# 8/8 [==============================] - 1s 141ms/step - loss: 0.1306 - accuracy: 0.9440 - val_loss: 0.1205 - val_accuracy: 0.9600
# Epoch 18/20
# 8/8 [==============================] - 1s 142ms/step - loss: 0.1582 - accuracy: 0.9260 - val_loss: 0.1925 - val_accuracy: 0.9400
# Epoch 19/20
# 8/8 [==============================] - 1s 138ms/step - loss: 0.1325 - accuracy: 0.9480 - val_loss: 0.1452 - val_accuracy: 0.9400
# Epoch 20/20
# 8/8 [==============================] - 1s 147ms/step - loss: 0.1128 - accuracy: 0.9520 - val_loss: 0.1552 - val_accuracy: 0.9300

# %%
train_model(3, 3, 3, 5)
# Out:
# Model: "sequential_6"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d_15 (Conv2D)           (None, 32, 32, 32)        896
# _________________________________________________________________
# max_pooling2d_10 (MaxPooling (None, 16, 16, 32)        0
# _________________________________________________________________
# dense_15 (Dense)             (None, 16, 16, 64)        2112
# _________________________________________________________________
# dropout_10 (Dropout)         (None, 16, 16, 64)        0
# _________________________________________________________________
# conv2d_16 (Conv2D)           (None, 16, 16, 64)        36928
# _________________________________________________________________
# max_pooling2d_11 (MaxPooling (None, 8, 8, 64)          0
# _________________________________________________________________
# dense_16 (Dense)             (None, 8, 8, 128)         8320
# _________________________________________________________________
# dropout_11 (Dropout)         (None, 8, 8, 128)         0
# _________________________________________________________________
# conv2d_17 (Conv2D)           (None, 8, 8, 128)         147584
# _________________________________________________________________
# flatten_5 (Flatten)          (None, 8192)              0
# _________________________________________________________________
# dense_17 (Dense)             (None, 2)                 16386
# =================================================================
# Total params: 212,226
# Trainable params: 212,226
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/5
# 8/8 [==============================] - 1s 118ms/step - loss: 15.9137 - accuracy: 0.5080 - val_loss: 0.5688 - val_accuracy: 0.7200
# Epoch 2/5
# 8/8 [==============================] - 1s 94ms/step - loss: 0.7912 - accuracy: 0.5860 - val_loss: 0.6403 - val_accuracy: 0.5800
# Epoch 3/5
# 8/8 [==============================] - 1s 94ms/step - loss: 0.5525 - accuracy: 0.7040 - val_loss: 0.4744 - val_accuracy: 0.7500
# Epoch 4/5
# 8/8 [==============================] - 1s 92ms/step - loss: 0.3629 - accuracy: 0.8780 - val_loss: 0.1836 - val_accuracy: 0.9200
# Epoch 5/5
# 8/8 [==============================] - 1s 88ms/step - loss: 0.2085 - accuracy: 0.9140 - val_loss: 0.1935 - val_accuracy: 0.9200

# %%
train_model(7, 5, 3, 20)
# Out:
# Model: "sequential_7"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d_18 (Conv2D)           (None, 32, 32, 32)        4736
# _________________________________________________________________
# max_pooling2d_12 (MaxPooling (None, 16, 16, 32)        0
# _________________________________________________________________
# dense_18 (Dense)             (None, 16, 16, 64)        2112
# _________________________________________________________________
# dropout_12 (Dropout)         (None, 16, 16, 64)        0
# _________________________________________________________________
# conv2d_19 (Conv2D)           (None, 16, 16, 64)        102464
# _________________________________________________________________
# max_pooling2d_13 (MaxPooling (None, 8, 8, 64)          0
# _________________________________________________________________
# dense_19 (Dense)             (None, 8, 8, 128)         8320
# _________________________________________________________________
# dropout_13 (Dropout)         (None, 8, 8, 128)         0
# _________________________________________________________________
# conv2d_20 (Conv2D)           (None, 8, 8, 128)         147584
# _________________________________________________________________
# flatten_6 (Flatten)          (None, 8192)              0
# _________________________________________________________________
# dense_20 (Dense)             (None, 2)                 16386
# =================================================================
# Total params: 281,602
# Trainable params: 281,602
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/20
# 8/8 [==============================] - 1s 154ms/step - loss: 22.1106 - accuracy: 0.5140 - val_loss: 0.9300 - val_accuracy: 0.5000
# Epoch 2/20
# 8/8 [==============================] - 1s 128ms/step - loss: 0.7109 - accuracy: 0.6560 - val_loss: 0.3082 - val_accuracy: 0.8900
# Epoch 3/20
# 8/8 [==============================] - 1s 118ms/step - loss: 0.3540 - accuracy: 0.8320 - val_loss: 0.2771 - val_accuracy: 0.8700
# Epoch 4/20
# 8/8 [==============================] - 1s 116ms/step - loss: 0.3432 - accuracy: 0.8440 - val_loss: 0.3833 - val_accuracy: 0.8400
# Epoch 5/20
# 8/8 [==============================] - 1s 123ms/step - loss: 0.3349 - accuracy: 0.8680 - val_loss: 0.2146 - val_accuracy: 0.9200
# Epoch 6/20
# 8/8 [==============================] - 1s 146ms/step - loss: 0.2105 - accuracy: 0.9140 - val_loss: 0.1751 - val_accuracy: 0.9200
# Epoch 7/20
# 8/8 [==============================] - 1s 121ms/step - loss: 0.1953 - accuracy: 0.9240 - val_loss: 0.1538 - val_accuracy: 0.9300
# Epoch 8/20
# 8/8 [==============================] - 1s 134ms/step - loss: 0.1539 - accuracy: 0.9300 - val_loss: 0.1126 - val_accuracy: 0.9600
# Epoch 9/20
# 8/8 [==============================] - 1s 123ms/step - loss: 0.1280 - accuracy: 0.9400 - val_loss: 0.0995 - val_accuracy: 0.9600
# Epoch 10/20
# 8/8 [==============================] - 1s 123ms/step - loss: 0.1315 - accuracy: 0.9520 - val_loss: 0.2161 - val_accuracy: 0.8900
# Epoch 11/20
# 8/8 [==============================] - 1s 133ms/step - loss: 0.1631 - accuracy: 0.9360 - val_loss: 0.1467 - val_accuracy: 0.9400
# Epoch 12/20
# 8/8 [==============================] - 1s 127ms/step - loss: 0.1444 - accuracy: 0.9400 - val_loss: 0.1687 - val_accuracy: 0.9300
# Epoch 13/20
# 8/8 [==============================] - 1s 117ms/step - loss: 0.1238 - accuracy: 0.9520 - val_loss: 0.1048 - val_accuracy: 0.9500
# Epoch 14/20
# 8/8 [==============================] - 1s 117ms/step - loss: 0.0914 - accuracy: 0.9680 - val_loss: 0.0825 - val_accuracy: 0.9700
# Epoch 15/20
# 8/8 [==============================] - 1s 119ms/step - loss: 0.0755 - accuracy: 0.9660 - val_loss: 0.0889 - val_accuracy: 0.9600
# Epoch 16/20
# 8/8 [==============================] - 1s 117ms/step - loss: 0.0577 - accuracy: 0.9840 - val_loss: 0.0922 - val_accuracy: 0.9600
# Epoch 17/20
# 8/8 [==============================] - 1s 117ms/step - loss: 0.0652 - accuracy: 0.9760 - val_loss: 0.0812 - val_accuracy: 0.9700
# Epoch 18/20
# 8/8 [==============================] - 1s 124ms/step - loss: 0.0437 - accuracy: 0.9820 - val_loss: 0.0810 - val_accuracy: 0.9700
# Epoch 19/20
# 8/8 [==============================] - 1s 127ms/step - loss: 0.0442 - accuracy: 0.9820 - val_loss: 0.1631 - val_accuracy: 0.9200
# Epoch 20/20
# 8/8 [==============================] - 1s 132ms/step - loss: 0.0784 - accuracy: 0.9600 - val_loss: 0.1057 - val_accuracy: 0.9500
